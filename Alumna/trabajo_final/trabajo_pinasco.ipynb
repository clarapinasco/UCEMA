# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import  matplotlib
web=pd.read_parquet('navegacion_web.pq', engine='pyarrow')

# %%
web
# Out:
#         user_id                              device_id     session_id  \
# 51760   9015447                 yWOTGT6B-WzQU514Cqx1gL  1644253316189
# 14885   8820027                 LP42_fstvBPogWjh_1bkCg  1642913715699
# 3992    5510567                 AKERRpRODjl02b39AjfNb8  1642459615372
# 131349  8665203                 SxeKxvgE3mkec-e21Ej-bm  1647229337062
# 25970   8409083                 CttzrxBwYiDT93zwK93Xmt  1643398529809
# ...         ...                                    ...            ...
# 214144  5557797                 ITao0pyc-03mus8Rf9JcN5  1651362376439
# 214111  6220646   2e8d803d-822f-400c-9338-99a57ca8de9e  1651361409595
# 214150  5910763   1869c436-faaf-41ee-aa01-fb7c31b80954  1651362633868
# 214142    87114  2e357941-9c2d-49b3-86a5-0799d80a7913R  1651362348345
# 214156  9742739   1aad33ac-8e00-4f1a-abf7-5ec15d537706  1651362831138
#
#           device_model        min_session_time  total_previous_sessions  \
# 51760          Android 2022-02-07 17:01:56.223                        1
# 14885          Android 2022-01-23 04:55:17.124                        1
# 3992           Android 2022-01-17 22:46:55.395                        1
# 131349         Android 2022-03-14 03:42:17.095                        1
# 25970          Android 2022-01-28 19:35:32.308                        1
# ...                ...                     ...                      ...
# 214144         Android 2022-04-30 23:46:16.457                        5
# 214111  moto g(8) plus 2022-04-30 23:30:09.595                       21
# 214150        SM-A515F 2022-04-30 23:50:33.868                       17
# 214142       SM-A705MN 2022-04-30 23:45:48.345                       10
# 214156    moto e5 play 2022-04-30 23:53:51.138                        2
#
#         total_previous_events              date_short  \
# 51760                       1 2022-01-01 00:11:51.858
# 14885                       9 2022-01-01 00:17:23.169
# 3992                        1 2022-01-01 00:22:28.720
# 131349                      9 2022-01-01 00:27:00.994
# 25970                       1 2022-01-01 00:28:48.352
# ...                       ...                     ...
# 214144                    132 2022-04-30 23:15:32.991
# 214111                    145 2022-04-30 23:29:00.824
# 214150                    235 2022-04-30 23:42:58.439
# 214142                    184 2022-04-30 23:45:03.997
# 214156                      6 2022-04-30 23:53:36.513
#
#         total_previous_vipphoto_selected  total_previous_vip360view_selected  \
# 51760                                  0                                   0
# 14885                                  0                                   0
# 3992                                   0                                   0
# 131349                                 0                                   0
# 25970                                  0                                   0
# ...                                  ...                                 ...
# 214144                                 0                                   0
# 214111                                 0                                   0
# 214150                                 0                                   0
# 214142                                 0                                   0
# 214156                                 0                                   0
#
#         ...       region  time_on_screen_prev  min_total_sessions_prev  \
# 51760   ...  Mexico City                  0.0                        0
# 14885   ...  Mexico City                286.0                        1
# 3992    ...  Mexico City                  0.0                        0
# 131349  ...  Mexico City                379.0                        1
# 25970   ...       México                  0.0                        0
# ...     ...          ...                  ...                      ...
# 214144  ...  Mexico City               6476.0                        3
# 214111  ...      Jalisco              87487.0                       18
# 214150  ...       Puebla              48362.0                       20
# 214142  ...      Hidalgo            5379364.0                       19
# 214156  ...       México                 90.0                        1
#
#         all_total_sessions_prev  total_sessions_prev  stock_id       date  \
# 51760                         0                    1       NaN        NaT
# 14885                         1                    2       NaN        NaT
# 3992                          0                    1       NaN        NaT
# 131349                        1                    2       NaN        NaT
# 25970                         0                    1       NaN        NaT
# ...                         ...                  ...       ...        ...
# 214144                        3                    4       NaN        NaT
# 214111                       18                   19       NaN        NaT
# 214150                       20                   17  182283.0 2022-05-01
# 214142                       19                   11       NaN        NaT
# 214156                        1                    2       NaN        NaT
#
#         user_with_reserve  reserved  avg_time_previous_sessions
# 51760                 0.0       0.0                    0.000000
# 14885                 0.0       0.0                  143.000000
# 3992                  0.0       0.0                    0.000000
# 131349                0.0       0.0                  189.500000
# 25970                 0.0       0.0                    0.000000
# ...                   ...       ...                         ...
# 214144                0.0       0.0                 1619.000000
# 214111                0.0       0.0                 4604.578947
# 214150                1.0       1.0                 2844.823529
# 214142                0.0       0.0               489033.090909
# 214156                0.0       0.0                   45.000000
#
# [214160 rows x 32 columns]

# %%
web.user_id.value_counts()
# Out:
# 4362580    84
# 8343164    70
# 8334191    59
# 3198949    53
# 5686051    49
#            ..
# 8280929     1
# 8812419     1
# 3874824     1
# 9702725     1
# 9742739     1
# Name: user_id, Length: 140084, dtype: int64

# %% [markdown]
# hacer dos notebooks

# %%
web.columns
# Out:
# Index(['user_id', 'device_id', 'session_id', 'device_model',
#        'min_session_time', 'total_previous_sessions', 'total_previous_events',
#        'date_short', 'total_previous_vipphoto_selected',
#        'total_previous_vip360view_selected',
#        'total_previous_catalogfilter_selected', 'total_previous_vip_viewed',
#        'total_previous_cataloglist_viewed', 'total_previous_home_viewed',
#        'total_previous_year_selected', 'total_previous_make_selected',
#        'total_previous_model_selected', 'total_previous_version_selected',
#        'total_previous_mileage_selected', 'total_previous_location_selected',
#        'total_previous_color_selected', 'city', 'region',
#        'time_on_screen_prev', 'min_total_sessions_prev',
#        'all_total_sessions_prev', 'total_sessions_prev', 'stock_id', 'date',
#        'user_with_reserve', 'reserved', 'avg_time_previous_sessions'],
#       dtype='object')

# %% [markdown]
# # Glosario

# %% [markdown]
# **user_id**=id del usuario
# **device_id**= id del dispositivo
# **min_session_time** = fecha de la primera sesión
# **total_sessions_prev**= numero de sesion
# **total_previous_events**= cantidad de eventos en esta sesión
# **date_short**= descartada
#     **total_previous_vipphoto_selected**=filtro del auto(evento)
#     **total_previous_catalogfilter_selected**= filtro del auto (evento)
#     **total_previous_vip_viewed**=filtro del auto (evento)
#     **total_previous_cataloglist_viewed**=filtro del auto (evento)
#     **total_previous_year_selected**=filtro del auto (evento)
#     **-total_previous_make_selected**=filtro del auto (evento)
#     **total_previous_model_selected**=filtro del auto (evento)
#     **total_previous_version_selected**=filtro del auto (evento)
#     **total_previous_mileage_selected**=filtro del auto (evento)
#     **total_previous_location_selected**=filtro del auto (evento)
#     **total_previous_color_selected**=filtro del auto (evento)
# **all_total_sessions_prev** cantidad de sesiones acumulados
# **total_previous_sessions**
# **all_total_previous_sessions**
# **stock_id**= id del sutp reservado
# **date**= fecha de reserva
# **user_with_reserve** = si reservo o no
# **reserved** = si reservo o no
# **avg_time_previous_sessions** = tiempo promedio en la pagina , medido en segundos
# **city**= cuidad de mexico
# **region**=  region de mexico
# **time_on_screen_prev**=  durecion en segundos de la sesion
# La columna total events muestra el total de todos los eventos de la session, los cuales no se muestran todos en este dataset.

# %%
print(f" El dataset muestra la actividad de los usuarios en la pagina web de KAVAK.Cuenta con  {web.shape[0]} sessiones en la web y {web.shape[1]} columnas que describen las acciones de dichos usuarios ")
# Out:
#  El dataset muestra la actividad de los usuarios en la pagina web de KAVAK.Cuenta con  214160 sessiones en la web y 32 columnas que describen las acciones de dichos usuarios

# %%
def percentageOfnull(df):
    nan_count = df.isna().sum().sort_values(ascending=False)
    nan_percentage = ((df.isna().sum()/df.isna().count())*100).round().sort_values(ascending=False)
    train_test_dtype = df.dtypes
    df_info = pd.concat([nan_count,nan_percentage,train_test_dtype],axis=1,keys=['Null Count','Null Percentage','DataTypes'])
    return df_info[df_info['Null Count']>0]

# %%
percentageOfnull(web)
# Out:
#           Null Count  Null Percentage       DataTypes
# date          195997             92.0  datetime64[ns]
# stock_id      195997             92.0         float64
# city           12816              6.0        category

# %% [markdown]
# Hay solo 3 columnas con datos nulos.  Las columnas de Date y Stock id tienen la misma cantidad de nulos, ¿Tendran una relación?
# La columna de city tiene solo 6% de datos nulos

# %%
web['city'].fillna(web['city'].mode()[0], inplace = True)

# %%
date_null=web.date.isna()
stock_id_null= web.stock_id.isna()
web[date_null != stock_id_null]
# Out:
# Empty DataFrame
# Columns: [user_id, device_id, session_id, device_model, min_session_time, total_previous_sessions, total_previous_events, date_short, total_previous_vipphoto_selected, total_previous_vip360view_selected, total_previous_catalogfilter_selected, total_previous_vip_viewed, total_previous_cataloglist_viewed, total_previous_home_viewed, total_previous_year_selected, total_previous_make_selected, total_previous_model_selected, total_previous_version_selected, total_previous_mileage_selected, total_previous_location_selected, total_previous_color_selected, city, region, time_on_screen_prev, min_total_sessions_prev, all_total_sessions_prev, total_sessions_prev, stock_id, date, user_with_reserve, reserved, avg_time_previous_sessions]
# Index: []
#
# [0 rows x 32 columns]

# %%
web.loc[web.reserved==1].isnull().sum()
# Out:
# user_id                                  0
# device_id                                0
# session_id                               0
# device_model                             0
# min_session_time                         0
# total_previous_sessions                  0
# total_previous_events                    0
# date_short                               0
# total_previous_vipphoto_selected         0
# total_previous_vip360view_selected       0
# total_previous_catalogfilter_selected    0
# total_previous_vip_viewed                0
# total_previous_cataloglist_viewed        0
# total_previous_home_viewed               0
# total_previous_year_selected             0
# total_previous_make_selected             0
# total_previous_model_selected            0
# total_previous_version_selected          0
# total_previous_mileage_selected          0
# total_previous_location_selected         0
# total_previous_color_selected            0
# city                                     0
# region                                   0
# time_on_screen_prev                      0
# min_total_sessions_prev                  0
# all_total_sessions_prev                  0
# total_sessions_prev                      0
# stock_id                                 0
# date                                     0
# user_with_reserve                        0
# reserved                                 0
# avg_time_previous_sessions               0
# dtype: int64

# %%
web.loc[web.user_id==3602521,['reserved','stock_id','date']]
# Out:
#        reserved  stock_id       date
# 18309       1.0  122184.0 2022-02-02
# 18327       1.0  122184.0 2022-02-02
# 18661       1.0  122184.0 2022-02-02
# 18509       1.0  122184.0 2022-02-02
# 18682       1.0  122184.0 2022-02-02
# 18813       1.0  122184.0 2022-02-02
# 19072       1.0  122184.0 2022-02-02
# 18981       1.0  122184.0 2022-02-02
# 31635       1.0  122184.0 2022-02-02
# 31214       1.0  122184.0 2022-02-02
# 19874       1.0  122184.0 2022-02-02
# 38270       1.0  125590.0 2022-02-03
# 38420       1.0  125590.0 2022-02-03
# 41132       0.0       NaN        NaT
# 38842       1.0  125590.0 2022-02-03
# 41108       0.0       NaN        NaT
# 54882       0.0       NaN        NaT

# %% [markdown]
# Las columnas de date y stock id tiene  mas de un 90% de datos nulos y estos coinciden en ambas columnas. Estas columnas tienen tantos datos nulos ya que corresponden  a la descripcion de los autos reservados por los usuarios. Los nulos coinciden con los False de 'reserved'

# %%
#web= web.drop(['date','stock_id'],axis=1)

# %%
import pandas_profiling
web.loc[:,web.columns !='user_id'].describe(        )
# Out:
#        total_previous_sessions  total_previous_events  \
# count            214160.000000           214160.00000
# mean                  6.721839              136.05466
# std                  15.737519              406.15579
# min                   1.000000                1.00000
# 25%                   1.000000               12.00000
# 50%                   3.000000               36.00000
# 75%                   6.000000              115.00000
# max                1388.000000            39953.00000
#
#        total_previous_vipphoto_selected  total_previous_vip360view_selected  \
# count                     214160.000000                       214160.000000
# mean                           5.022619                            0.549743
# std                           49.460406                            5.033431
# min                            0.000000                            0.000000
# 25%                            0.000000                            0.000000
# 50%                            0.000000                            0.000000
# 75%                            0.000000                            0.000000
# max                         8286.000000                          694.000000
#
#        total_previous_catalogfilter_selected  total_previous_vip_viewed  \
# count                          214160.000000              214160.000000
# mean                               28.677615                  25.250299
# std                               122.384672                  81.485442
# min                                 0.000000                   0.000000
# 25%                                 0.000000                   1.000000
# 50%                                 2.000000                   5.000000
# 75%                                18.000000                  20.000000
# max                             11739.000000                6743.000000
#
#        total_previous_cataloglist_viewed  total_previous_home_viewed  \
# count                      214160.000000               214160.000000
# mean                           35.365283                    4.779613
# std                           177.395937                   22.261192
# min                             0.000000                    0.000000
# 25%                             0.000000                    0.000000
# 50%                             0.000000                    0.000000
# 75%                            14.000000                    3.000000
# max                         21358.000000                 2546.000000
#
#        total_previous_year_selected  total_previous_make_selected  ...  \
# count                 214160.000000                 214160.000000  ...
# mean                       0.372913                      0.376718  ...
# std                        1.913053                      1.884517  ...
# min                        0.000000                      0.000000  ...
# 25%                        0.000000                      0.000000  ...
# 50%                        0.000000                      0.000000  ...
# 75%                        0.000000                      0.000000  ...
# max                      320.000000                    226.000000  ...
#
#        total_previous_location_selected  total_previous_color_selected  \
# count                     214160.000000                  214160.000000
# mean                           0.262229                       0.247086
# std                            1.538530                       1.416469
# min                            0.000000                       0.000000
# 25%                            0.000000                       0.000000
# 50%                            0.000000                       0.000000
# 75%                            0.000000                       0.000000
# max                          207.000000                     213.000000
#
#        time_on_screen_prev  min_total_sessions_prev  all_total_sessions_prev  \
# count         2.141600e+05            214160.000000            214160.000000
# mean          8.518372e+04                 5.914989                 5.914989
# std           6.172415e+05                15.261105                15.261105
# min           0.000000e+00                 0.000000                 0.000000
# 25%           1.920000e+02                 1.000000                 1.000000
# 50%           9.140000e+02                 2.000000                 2.000000
# 75%           3.426000e+03                 5.000000                 5.000000
# max           1.837662e+07              1410.000000              1410.000000
#
#        total_sessions_prev       stock_id  user_with_reserve      reserved  \
# count        214160.000000   18163.000000       214160.00000  214160.00000
# mean              6.660035  147558.372295            0.08481       0.08481
# std              14.556284   28065.350928            0.27860       0.27860
# min               1.000000    4258.000000            0.00000       0.00000
# 25%               2.000000  131200.000000            0.00000       0.00000
# 50%               3.000000  155340.000000            0.00000       0.00000
# 75%               6.000000  166279.000000            0.00000       0.00000
# max            1361.000000  185697.000000            1.00000       1.00000
#
#        avg_time_previous_sessions
# count                2.141600e+05
# mean                 9.131869e+03
# std                  9.233204e+04
# min                  0.000000e+00
# 25%                  7.350000e+01
# 50%                  2.530000e+02
# 75%                  6.207297e+02
# max                  5.648626e+06
#
# [8 rows x 23 columns]

# %%
web.dtypes
# Out:
# user_id                                           int64
# device_id                                        object
# session_id                                       object
# device_model                                   category
# min_session_time                         datetime64[ns]
# total_previous_sessions                           int64
# total_previous_events                             int64
# date_short                               datetime64[ns]
# total_previous_vipphoto_selected                  int64
# total_previous_vip360view_selected                int64
# total_previous_catalogfilter_selected             int64
# total_previous_vip_viewed                         int64
# total_previous_cataloglist_viewed                 int64
# total_previous_home_viewed                        int64
# total_previous_year_selected                      int64
# total_previous_make_selected                      int64
# total_previous_model_selected                     int64
# total_previous_version_selected                   int64
# total_previous_mileage_selected                   int64
# total_previous_location_selected                  int64
# total_previous_color_selected                     int64
# city                                           category
# region                                         category
# time_on_screen_prev                             float64
# min_total_sessions_prev                           int64
# all_total_sessions_prev                           int64
# total_sessions_prev                               int64
# stock_id                                        float64
# date                                     datetime64[ns]
# user_with_reserve                               float64
# reserved                                        float64
# avg_time_previous_sessions                      float64
# dtype: object

# %% [markdown]
# # Column Names Adjastment

# %%
web[web.user_with_reserve!=web.reserved]
# Out:
# Empty DataFrame
# Columns: [user_id, device_id, session_id, device_model, min_session_time, total_previous_sessions, total_previous_events, date_short, total_previous_vipphoto_selected, total_previous_vip360view_selected, total_previous_catalogfilter_selected, total_previous_vip_viewed, total_previous_cataloglist_viewed, total_previous_home_viewed, total_previous_year_selected, total_previous_make_selected, total_previous_model_selected, total_previous_version_selected, total_previous_mileage_selected, total_previous_location_selected, total_previous_color_selected, city, region, time_on_screen_prev, min_total_sessions_prev, all_total_sessions_prev, total_sessions_prev, stock_id, date, user_with_reserve, reserved, avg_time_previous_sessions]
# Index: []
#
# [0 rows x 32 columns]

# %%
#dado que son iguales, borro una de las dos
web=web.drop('user_with_reserve',axis=1)

# %%
# las acciones son de esta sesion por lo que decidi borrar el "previous" para no confundir
def normalize(df):
  df.columns = df.columns.str.replace("_previous","")
normalize(web)
web
# Out:
#         user_id                              device_id     session_id  \
# 51760   9015447                 yWOTGT6B-WzQU514Cqx1gL  1644253316189
# 14885   8820027                 LP42_fstvBPogWjh_1bkCg  1642913715699
# 3992    5510567                 AKERRpRODjl02b39AjfNb8  1642459615372
# 131349  8665203                 SxeKxvgE3mkec-e21Ej-bm  1647229337062
# 25970   8409083                 CttzrxBwYiDT93zwK93Xmt  1643398529809
# ...         ...                                    ...            ...
# 214144  5557797                 ITao0pyc-03mus8Rf9JcN5  1651362376439
# 214111  6220646   2e8d803d-822f-400c-9338-99a57ca8de9e  1651361409595
# 214150  5910763   1869c436-faaf-41ee-aa01-fb7c31b80954  1651362633868
# 214142    87114  2e357941-9c2d-49b3-86a5-0799d80a7913R  1651362348345
# 214156  9742739   1aad33ac-8e00-4f1a-abf7-5ec15d537706  1651362831138
#
#           device_model        min_session_time  total_sessions  total_events  \
# 51760          Android 2022-02-07 17:01:56.223               1             1
# 14885          Android 2022-01-23 04:55:17.124               1             9
# 3992           Android 2022-01-17 22:46:55.395               1             1
# 131349         Android 2022-03-14 03:42:17.095               1             9
# 25970          Android 2022-01-28 19:35:32.308               1             1
# ...                ...                     ...             ...           ...
# 214144         Android 2022-04-30 23:46:16.457               5           132
# 214111  moto g(8) plus 2022-04-30 23:30:09.595              21           145
# 214150        SM-A515F 2022-04-30 23:50:33.868              17           235
# 214142       SM-A705MN 2022-04-30 23:45:48.345              10           184
# 214156    moto e5 play 2022-04-30 23:53:51.138               2             6
#
#                     date_short  total_vipphoto_selected  \
# 51760  2022-01-01 00:11:51.858                        0
# 14885  2022-01-01 00:17:23.169                        0
# 3992   2022-01-01 00:22:28.720                        0
# 131349 2022-01-01 00:27:00.994                        0
# 25970  2022-01-01 00:28:48.352                        0
# ...                        ...                      ...
# 214144 2022-04-30 23:15:32.991                        0
# 214111 2022-04-30 23:29:00.824                        0
# 214150 2022-04-30 23:42:58.439                        0
# 214142 2022-04-30 23:45:03.997                        0
# 214156 2022-04-30 23:53:36.513                        0
#
#         total_vip360view_selected  ...         city       region  \
# 51760                           0  ...  Mexico City  Mexico City
# 14885                           0  ...   Iztapalapa  Mexico City
# 3992                            0  ...  Mexico City  Mexico City
# 131349                          0  ...  Mexico City  Mexico City
# 25970                           0  ...  Mexico City       México
# ...                           ...  ...          ...          ...
# 214144                          0  ...  Mexico City  Mexico City
# 214111                          0  ...  Guadalajara      Jalisco
# 214150                          0  ...  Puebla City       Puebla
# 214142                          0  ...     Tizayuca      Hidalgo
# 214156                          0  ...      Tecamac       México
#
#         time_on_screen_prev  min_total_sessions_prev  all_total_sessions_prev  \
# 51760                   0.0                        0                        0
# 14885                 286.0                        1                        1
# 3992                    0.0                        0                        0
# 131349                379.0                        1                        1
# 25970                   0.0                        0                        0
# ...                     ...                      ...                      ...
# 214144               6476.0                        3                        3
# 214111              87487.0                       18                       18
# 214150              48362.0                       20                       20
# 214142            5379364.0                       19                       19
# 214156                 90.0                        1                        1
#
#         total_sessions_prev  stock_id       date  reserved  avg_time_sessions
# 51760                     1       NaN        NaT       0.0           0.000000
# 14885                     2       NaN        NaT       0.0         143.000000
# 3992                      1       NaN        NaT       0.0           0.000000
# 131349                    2       NaN        NaT       0.0         189.500000
# 25970                     1       NaN        NaT       0.0           0.000000
# ...                     ...       ...        ...       ...                ...
# 214144                    4       NaN        NaT       0.0        1619.000000
# 214111                   19       NaN        NaT       0.0        4604.578947
# 214150                   17  182283.0 2022-05-01       1.0        2844.823529
# 214142                   11       NaN        NaT       0.0      489033.090909
# 214156                    2       NaN        NaT       0.0          45.000000
#
# [214160 rows x 31 columns]

# %% [markdown]
# ¿ es min_session_time de verdad la primera sesion? ¿ porque un usuario  tiene dos distintas primeras sesiones?¿ que es short_date?

# %%
web=web.rename(columns={'min_session_time':'session_date'})

# %%
web.loc[web.user_id==8820027]
# Out:
#        user_id               device_id     session_id device_model  \
# 14885  8820027  LP42_fstvBPogWjh_1bkCg  1642913715699      Android
# 23038  8820027  LP42_fstvBPogWjh_1bkCg  1643236351710      Android
#
#                  session_date  total_sessions  total_events  \
# 14885 2022-01-23 04:55:17.124               1             9
# 23038 2022-01-26 22:32:31.975               2            23
#
#                    date_short  total_vipphoto_selected  \
# 14885 2022-01-01 00:17:23.169                        0
# 23038 2022-01-23 05:03:18.252                        0
#
#        total_vip360view_selected  ...        city       region  \
# 14885                          0  ...  Iztapalapa  Mexico City
# 23038                          0  ...  Iztapalapa  Mexico City
#
#        time_on_screen_prev  min_total_sessions_prev  all_total_sessions_prev  \
# 14885                286.0                        1                        1
# 23038                767.0                        2                        2
#
#        total_sessions_prev  stock_id  date  reserved  avg_time_sessions
# 14885                    2       NaN   NaT       0.0         143.000000
# 23038                    3       NaN   NaT       0.0         255.666667
#
# [2 rows x 31 columns]

# %%
web['mes_sesion']=web['session_date'].dt.month

# %%
web.loc[~web.date.isna(),['session_date','date','date_short']]
# Out:
#                   session_date       date              date_short
# 28429  2022-01-29 20:40:32.448 2022-02-09 2022-01-01 01:56:47.633
# 55899  2022-02-08 23:24:03.140 2022-02-09 2022-01-01 02:55:59.068
# 24416  2022-01-28 01:33:19.436 2022-01-31 2022-01-01 08:45:27.913
# 43108  2022-02-04 06:40:45.200 2022-02-16 2022-01-01 10:59:55.174
# 143481 2022-03-20 21:45:20.961 2022-03-21 2022-01-01 20:25:49.764
# ...                        ...        ...                     ...
# 214123 2022-04-30 23:36:00.892 2022-05-02 2022-04-30 22:57:24.940
# 214074 2022-04-30 23:08:49.961 2022-05-02 2022-04-30 23:07:46.702
# 214072 2022-04-30 23:08:34.191 2022-05-01 2022-04-30 23:07:54.712
# 214079 2022-04-30 23:11:02.489 2022-05-01 2022-04-30 23:10:20.521
# 214150 2022-04-30 23:50:33.868 2022-05-01 2022-04-30 23:42:58.439
#
# [18163 rows x 3 columns]

# %%
web=web.drop('date_short',axis=1)

# %%
web=web.rename(columns={'date of reservation':'date'})

# %% [markdown]
# Short date es anterior a first_session_date por lo que la descarto.
# La columna de date hace referencia a la fecha de reserva-

# %%
web = web.rename(columns={'time_on_screen_prev': 'seconds on screen'})
web['muinutes on screen'] = web['seconds on screen'] / 60

# %%
web=web.rename(columns={'avg_time_sessions': 'avg seconds on screen'})
web['avg minutes on screen'] = web['avg seconds on screen'] / 60

# %% [markdown]
# **Null Analysis**

# %%
web["mes de reserva"] = web.date.dt.month
web['dia de reserva'] =web.date.dt.day
web
# Out:
#         user_id                              device_id     session_id  \
# 51760   9015447                 yWOTGT6B-WzQU514Cqx1gL  1644253316189
# 14885   8820027                 LP42_fstvBPogWjh_1bkCg  1642913715699
# 3992    5510567                 AKERRpRODjl02b39AjfNb8  1642459615372
# 131349  8665203                 SxeKxvgE3mkec-e21Ej-bm  1647229337062
# 25970   8409083                 CttzrxBwYiDT93zwK93Xmt  1643398529809
# ...         ...                                    ...            ...
# 214144  5557797                 ITao0pyc-03mus8Rf9JcN5  1651362376439
# 214111  6220646   2e8d803d-822f-400c-9338-99a57ca8de9e  1651361409595
# 214150  5910763   1869c436-faaf-41ee-aa01-fb7c31b80954  1651362633868
# 214142    87114  2e357941-9c2d-49b3-86a5-0799d80a7913R  1651362348345
# 214156  9742739   1aad33ac-8e00-4f1a-abf7-5ec15d537706  1651362831138
#
#           device_model            session_date  total_sessions  total_events  \
# 51760          Android 2022-02-07 17:01:56.223               1             1
# 14885          Android 2022-01-23 04:55:17.124               1             9
# 3992           Android 2022-01-17 22:46:55.395               1             1
# 131349         Android 2022-03-14 03:42:17.095               1             9
# 25970          Android 2022-01-28 19:35:32.308               1             1
# ...                ...                     ...             ...           ...
# 214144         Android 2022-04-30 23:46:16.457               5           132
# 214111  moto g(8) plus 2022-04-30 23:30:09.595              21           145
# 214150        SM-A515F 2022-04-30 23:50:33.868              17           235
# 214142       SM-A705MN 2022-04-30 23:45:48.345              10           184
# 214156    moto e5 play 2022-04-30 23:53:51.138               2             6
#
#         total_vipphoto_selected  total_vip360view_selected  \
# 51760                         0                          0
# 14885                         0                          0
# 3992                          0                          0
# 131349                        0                          0
# 25970                         0                          0
# ...                         ...                        ...
# 214144                        0                          0
# 214111                        0                          0
# 214150                        0                          0
# 214142                        0                          0
# 214156                        0                          0
#
#         total_catalogfilter_selected  ...  total_sessions_prev  stock_id  \
# 51760                              0  ...                    1       NaN
# 14885                              5  ...                    2       NaN
# 3992                               0  ...                    1       NaN
# 131349                             2  ...                    2       NaN
# 25970                              0  ...                    1       NaN
# ...                              ...  ...                  ...       ...
# 214144                            32  ...                    4       NaN
# 214111                            10  ...                   19       NaN
# 214150                            34  ...                   17  182283.0
# 214142                             0  ...                   11       NaN
# 214156                             0  ...                    2       NaN
#
#              date  reserved  avg seconds on screen  mes_sesion  \
# 51760         NaT       0.0               0.000000           2
# 14885         NaT       0.0             143.000000           1
# 3992          NaT       0.0               0.000000           1
# 131349        NaT       0.0             189.500000           3
# 25970         NaT       0.0               0.000000           1
# ...           ...       ...                    ...         ...
# 214144        NaT       0.0            1619.000000           4
# 214111        NaT       0.0            4604.578947           4
# 214150 2022-05-01       1.0            2844.823529           4
# 214142        NaT       0.0          489033.090909           4
# 214156        NaT       0.0              45.000000           4
#
#         muinutes on screen  avg minutes on screen  mes de reserva  \
# 51760             0.000000               0.000000             NaN
# 14885             4.766667               2.383333             NaN
# 3992              0.000000               0.000000             NaN
# 131349            6.316667               3.158333             NaN
# 25970             0.000000               0.000000             NaN
# ...                    ...                    ...             ...
# 214144          107.933333              26.983333             NaN
# 214111         1458.116667              76.742982             NaN
# 214150          806.033333              47.413725             5.0
# 214142        89656.066667            8150.551515             NaN
# 214156            1.500000               0.750000             NaN
#
#         dia de reserva
# 51760              NaN
# 14885              NaN
# 3992               NaN
# 131349             NaN
# 25970              NaN
# ...                ...
# 214144             NaN
# 214111             NaN
# 214150             1.0
# 214142             NaN
# 214156             NaN
#
# [214160 rows x 35 columns]

# %% [markdown]
# ## Outliers

# %%
web.nlargest(10,'muinutes on screen')
# Out:
#         user_id                              device_id     session_id  \
# 211551  8263381  f518c3fc-993e-47f3-916a-4f274fee3e92R  1651235051108
# 118990  6135780  fac8cf56-03b5-4687-a734-074b180d3060R  1646713382976
# 147776  3608410  f1d8bc56-70cc-492d-a5de-b941d873d5a4R  1648008206521
# 180373  5798011  eaebce85-167e-4916-a1fd-85d40a45baa9R  1649652680685
# 114102  9297204  af5ca176-ffde-4efd-b4fa-aa5f05f463bcR  1646506976406
# 213910  3767136  ad0a8282-3b81-425d-b1b9-bc963ed7dc3dR  1651354120315
# 213924  9741887  19434b56-1451-466b-b77a-5eabeaa8a4dbR  1651354613153
# 198499  5495818  f2fb9fd8-e118-4b20-a600-784c3956a9a1R  1650640789059
# 181390  6390583  9e443378-0591-41a9-9e87-912a9bdf6c97R  1649715884846
# 201199    39785  5476169f-16b5-46c8-9bc7-cab0feaef739R  1650763619173
#
#         device_model            session_date  total_sessions  total_events  \
# 211551    M2003J15SC 2022-04-29 12:24:11.108               3           105
# 118990  Redmi Note 7 2022-03-08 04:23:02.976               7           942
# 147776     moto g 5G 2022-03-23 04:03:26.521               3           275
# 180373      ZTE 8010 2022-04-11 04:51:20.685              36           643
# 114102       LG-M700 2022-03-05 19:02:56.406               7            98
# 213910       ELE-L04 2022-04-30 21:28:40.315              22           286
# 213924       YAL-L21 2022-04-30 21:36:53.153              29           269
# 198499       STK-LX3 2022-04-22 15:19:49.059              31          1007
# 181390     moto e(7) 2022-04-11 22:24:44.846              12            72
# 201199      SM-N9600 2022-04-24 01:26:59.173              31           497
#
#         total_vipphoto_selected  total_vip360view_selected  \
# 211551                        0                          0
# 118990                        0                          0
# 147776                        0                          0
# 180373                        0                          0
# 114102                        0                          0
# 213910                        0                          0
# 213924                        0                          0
# 198499                        0                          0
# 181390                        0                          0
# 201199                        0                          0
#
#         total_catalogfilter_selected  ...  total_sessions_prev  stock_id  \
# 211551                             0  ...                    4       NaN
# 118990                           335  ...                    8       NaN
# 147776                            35  ...                    4       NaN
# 180373                             3  ...                   35       NaN
# 114102                            16  ...                    8       NaN
# 213910                            56  ...                   23  160455.0
# 213924                             0  ...                   86       NaN
# 198499                           445  ...                   32       NaN
# 181390                             0  ...                   13       NaN
# 201199                            96  ...                   32       NaN
#
#              date  reserved  avg seconds on screen  mes_sesion  \
# 211551        NaT       0.0           4.594154e+06           4
# 118990        NaT       0.0           1.992985e+06           3
# 147776        NaT       0.0           3.670099e+06           3
# 180373        NaT       0.0           4.158981e+05           4
# 114102        NaT       0.0           1.819401e+06           3
# 213910 2022-05-05       1.0           5.757930e+05           4
# 213924        NaT       0.0           1.531087e+05           4
# 198499        NaT       0.0           4.094359e+05           4
# 181390        NaT       0.0           9.766029e+05           4
# 201199        NaT       0.0           3.951408e+05           4
#
#         muinutes on screen  avg minutes on screen  mes de reserva  \
# 211551       306276.933333           76569.233333             NaN
# 118990       265731.383333           33216.422917             NaN
# 147776       244673.266667           61168.316667             NaN
# 180373       242607.233333            6931.635238             NaN
# 114102       242586.750000           30323.343750             NaN
# 213910       220720.633333            9596.549275             5.0
# 213924       219455.800000            2551.811628             NaN
# 198499       218365.816667            6823.931771             NaN
# 181390       211597.300000           16276.715385             NaN
# 201199       210741.766667            6585.680208             NaN
#
#         dia de reserva
# 211551             NaN
# 118990             NaN
# 147776             NaN
# 180373             NaN
# 114102             NaN
# 213910             5.0
# 213924             NaN
# 198499             NaN
# 181390             NaN
# 201199             NaN
#
# [10 rows x 35 columns]

# %%
sns.boxplot( y=web['muinutes on screen']);
plt.xticks(rotation = 90)
plt.show()

# %%
usuarios_con_reserva=web.groupby('user_id').agg(reserved=('reserved','sum'))
usuarios_con_reserva
# Out:
#          reserved
# user_id
# 104           0.0
# 136           1.0
# 137           0.0
# 166           0.0
# 201           0.0
# ...           ...
# 9756022       0.0
# 9759725       0.0
# 9776787       0.0
# 9790603       0.0
# 9856417       0.0
#
# [140084 rows x 1 columns]

# %%
usuarios_con_reserva.value_counts()
# Out:
# reserved
# 0.0         131221
# 1.0           5026
# 2.0           1916
# 3.0            835
# 4.0            416
# 5.0            209
# 6.0            144
# 7.0             98
# 8.0             56
# 10.0            40
# 9.0             38
# 11.0            19
# 12.0            12
# 13.0            11
# 18.0             7
# 14.0             7
# 15.0             5
# 17.0             4
# 16.0             3
# 19.0             3
# 20.0             3
# 21.0             2
# 26.0             2
# 24.0             1
# 25.0             1
# 27.0             1
# 32.0             1
# 37.0             1
# 39.0             1
# 45.0             1
# dtype: int64

# %%
usuarios_con_reserva.boxplot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Busqueda de Objetivo

# %%
cantidad_de_dispositivos=web.groupby(web.user_id).agg(devices_used=('device_id','nunique'),reserved=('reserved','sum'))
cantidad_de_dispositivos
# Out:
#          devices_used  reserved
# user_id
# 104                 1       0.0
# 136                 1       1.0
# 137                 1       0.0
# 166                 1       0.0
# 201                 1       0.0
# ...               ...       ...
# 9756022             1       0.0
# 9759725             1       0.0
# 9776787             1       0.0
# 9790603             1       0.0
# 9856417             1       0.0
#
# [140084 rows x 2 columns]

# %%
cantidad_de_dispositivos.devices_used.unique()
# Out:
# array([ 1,  3,  2,  6,  7,  5, 11,  4,  8,  9], dtype=int64)

# %%
cantidad_de_dispositivos.loc[cantidad_de_dispositivos.devices_used==11]
# Out:
#          devices_used  reserved
# user_id
# 2066               11       0.0
# 6126706            11       0.0

# %%
cantidad_de_dispositivos.loc[cantidad_de_dispositivos.devices_used==9]
# Out:
#          devices_used  reserved
# user_id
# 4362580             9       0.0

# %%
cantidad_de_dispositivos.loc[cantidad_de_dispositivos.devices_used==8]
# Out:
#          devices_used  reserved
# user_id
# 3596077             8       0.0
# 3602521             8      14.0
# 5327592             8       4.0
# 5383638             8       0.0
# 5665925             8       2.0
# 5938616             8       1.0
# 8769689             8       2.0
# 9373330             8       6.0

# %%
web.loc[web.user_id==3602521,['reserved','stock_id','session_date']]
# Out:
#        reserved  stock_id            session_date
# 18309       1.0  122184.0 2022-01-24 21:54:11.921
# 18327       1.0  122184.0 2022-01-24 22:02:49.167
# 18661       1.0  122184.0 2022-01-25 00:09:17.685
# 18509       1.0  122184.0 2022-01-24 23:11:59.274
# 18682       1.0  122184.0 2022-01-25 00:17:29.392
# 18813       1.0  122184.0 2022-01-25 01:09:12.916
# 19072       1.0  122184.0 2022-01-25 02:47:22.332
# 18981       1.0  122184.0 2022-01-25 02:13:32.303
# 31635       1.0  122184.0 2022-01-31 01:15:21.281
# 31214       1.0  122184.0 2022-01-30 22:43:41.263
# 19874       1.0  122184.0 2022-01-25 15:05:07.931
# 38270       1.0  125590.0 2022-02-02 17:37:16.895
# 38420       1.0  125590.0 2022-02-02 18:37:52.427
# 41132       0.0       NaN 2022-02-03 18:18:55.793
# 38842       1.0  125590.0 2022-02-02 21:24:30.996
# 41108       0.0       NaN 2022-02-03 18:10:18.986
# 54882       0.0       NaN 2022-02-08 17:41:32.759

# %% [markdown]
# Este usuario  entro 17 veces a la pagina web, con 8 dispositivos distintos, En 14 de esas sesiones reservo dos autos.¿Que significa que reserve el mismo auto en distintas sesiones?

# %% [markdown]
# para medir la conversion trendría que hacer un nunique de stock_id ? o un sum de reserved?

# %%
print(web.stock_id.nunique(),web.reserved.sum())
# Out:
# 8065 18163.0

# %% [markdown]
# ## USUARIOS QUE RESERVARON

# %%
conversion= web.loc[web['reserved']== 1]
conversion=conversion.drop(columns=['all_total_sessions_prev','min_total_sessions_prev','total_sessions_prev'])

# %%
conversion
# Out:
#         user_id                              device_id     session_id  \
# 28429   8589349                 0zP5U3gE18RE2JYUaVAyWq  1643488571797
# 55899   5592873                 ZyuIJgiYpARmHvcKdszy55  1644362643111
# 24416   3933163                 QF6jZinvSMeJesEB4-o3NC  1643333597269
# 43108   4741881                 FoMlN5X8t5qeeKQLsf-kL3  1643956845114
# 143481  9427841                 0UcRRMRpjwRT-a7xOn35Wo  1647812720932
# ...         ...                                    ...            ...
# 214123  9301780                 xGbfyuLvqAt1EDXSvAPtBf  1651361760856
# 214074  9565318   f90b950b-02dd-4c32-80a3-6a03f5da350f  1651360129961
# 214072  6275577  73785c9c-31e6-4379-bfec-d11f6d0a5865R  1651360114191
# 214079  6275577  73785c9c-31e6-4379-bfec-d11f6d0a5865R  1651360262489
# 214150  5910763   1869c436-faaf-41ee-aa01-fb7c31b80954  1651362633868
#
#           device_model            session_date  total_sessions  total_events  \
# 28429          Android 2022-01-29 20:40:32.448               1             1
# 55899          Android 2022-02-08 23:24:03.140               1            16
# 24416          Android 2022-01-28 01:33:19.436               1             2
# 43108          Android 2022-02-04 06:40:45.200               1             7
# 143481         Android 2022-03-20 21:45:20.961               1             8
# ...                ...                     ...             ...           ...
# 214123          iPhone 2022-04-30 23:36:00.892               1           260
# 214074  moto g(8) plus 2022-04-30 23:08:49.961              34           725
# 214072  moto g(7) plus 2022-04-30 23:08:34.191              10           187
# 214079  moto g(7) plus 2022-04-30 23:11:02.489              11           195
# 214150        SM-A515F 2022-04-30 23:50:33.868              17           235
#
#         total_vipphoto_selected  total_vip360view_selected  \
# 28429                         0                          0
# 55899                         0                          0
# 24416                         0                          0
# 43108                         0                          0
# 143481                        0                          1
# ...                         ...                        ...
# 214123                        0                          4
# 214074                        0                          0
# 214072                        0                          0
# 214079                        0                          0
# 214150                        0                          0
#
#         total_catalogfilter_selected  ...  seconds on screen  stock_id  \
# 28429                              0  ...                0.0   46862.0
# 55899                              0  ...               99.0   45505.0
# 24416                              0  ...                3.0  159775.0
# 43108                              4  ...              143.0  161572.0
# 143481                             0  ...              272.0  157393.0
# ...                              ...  ...                ...       ...
# 214123                            22  ...             6251.0  101296.0
# 214074                           109  ...          1302242.0  185337.0
# 214072                             0  ...          4232396.0  140696.0
# 214079                             0  ...          4232502.0  140696.0
# 214150                            34  ...            48362.0  182283.0
#
#              date  reserved  avg seconds on screen  mes_sesion  \
# 28429  2022-02-09       1.0               0.000000           1
# 55899  2022-02-09       1.0              49.500000           2
# 24416  2022-01-31       1.0               1.500000           1
# 43108  2022-02-16       1.0              71.500000           2
# 143481 2022-03-21       1.0             136.000000           3
# ...           ...       ...                    ...         ...
# 214123 2022-05-02       1.0            3125.500000           4
# 214074 2022-05-02       1.0           38301.235294           4
# 214072 2022-05-01       1.0          302314.000000           4
# 214079 2022-05-01       1.0          282166.800000           4
# 214150 2022-05-01       1.0            2844.823529           4
#
#         muinutes on screen  avg minutes on screen  mes de reserva  \
# 28429             0.000000               0.000000             2.0
# 55899             1.650000               0.825000             2.0
# 24416             0.050000               0.025000             1.0
# 43108             2.383333               1.191667             2.0
# 143481            4.533333               2.266667             3.0
# ...                    ...                    ...             ...
# 214123          104.183333              52.091667             5.0
# 214074        21704.033333             638.353922             5.0
# 214072        70539.933333            5038.566667             5.0
# 214079        70541.700000            4702.780000             5.0
# 214150          806.033333              47.413725             5.0
#
#         dia de reserva
# 28429              9.0
# 55899              9.0
# 24416             31.0
# 43108             16.0
# 143481            21.0
# ...                ...
# 214123             2.0
# 214074             2.0
# 214072             1.0
# 214079             1.0
# 214150             1.0
#
# [18163 rows x 32 columns]

# %%
conversion.isna().sum()
# Out:
# user_id                         0
# device_id                       0
# session_id                      0
# device_model                    0
# session_date                    0
# total_sessions                  0
# total_events                    0
# total_vipphoto_selected         0
# total_vip360view_selected       0
# total_catalogfilter_selected    0
# total_vip_viewed                0
# total_cataloglist_viewed        0
# total_home_viewed               0
# total_year_selected             0
# total_make_selected             0
# total_model_selected            0
# total_version_selected          0
# total_mileage_selected          0
# total_location_selected         0
# total_color_selected            0
# city                            0
# region                          0
# seconds on screen               0
# stock_id                        0
# date                            0
# reserved                        0
# avg seconds on screen           0
# mes_sesion                      0
# muinutes on screen              0
# avg minutes on screen           0
# mes de reserva                  0
# dia de reserva                  0
# dtype: int64

# %% [markdown]
# ## Conversion como cantidad de Reservas

# %%
tasa_de_conversion=web.groupby('mes_sesion').agg(cantidad_de_reservas=('reserved','sum'),
                                         cantidad_de_sessiones=('session_id','count'),)
tasa_de_conversion['porcentaje_de_reservas']=tasa_de_conversion.cantidad_de_reservas/tasa_de_conversion.cantidad_de_sessiones*100
tasa_de_conversion
# Out:
#             cantidad_de_reservas  cantidad_de_sessiones  \
# mes_sesion
# 1                         3369.0                  34064
# 2                         6249.0                  70593
# 3                         5060.0                  60024
# 4                         3485.0                  49479
#
#             porcentaje_de_reservas
# mes_sesion
# 1                         9.890207
# 2                         8.852152
# 3                         8.429961
# 4                         7.043392

# %% [markdown]
# (hay usuarios que entraron al sitio por primera vez un  mes y reservaron  el siguiente mes)

# %%
tasa_de_conversion.porcentaje_de_reservas.plot.line( ylim = [0, 11])
plt.title('variacion de la tasa de conversion')
plt.xlabel('mes del 2022')
plt.ylabel('tasa de conversion')
plt.xticks([1,2,3,4])
plt.show()

# %% [markdown]
# ## Conversion como cantidad de autos reservados

# %%
tasa_de_conversion_2=web.groupby('mes_sesion').agg(cantidad_de_reservas=('stock_id','nunique'),
                                         cantidad_de_sessiones=('session_id','count'))
tasa_de_conversion_2['porcentaje_de_reservas']=tasa_de_conversion_2.cantidad_de_reservas/tasa_de_conversion_2.cantidad_de_sessiones*100
tasa_de_conversion_2
# Out:
#             cantidad_de_reservas  cantidad_de_sessiones  \
# mes_sesion
# 1                           1671                  34064
# 2                           3054                  70593
# 3                           2770                  60024
# 4                           2002                  49479
#
#             porcentaje_de_reservas
# mes_sesion
# 1                         4.905472
# 2                         4.326208
# 3                         4.614821
# 4                         4.046161

# %%
tasa_de_conversion_2.porcentaje_de_reservas.plot.line( ylim = [0, 6])
plt.title('variacion de la tasa de conversion')
plt.xlabel('mes del 2022')
plt.ylabel('tasa de conversion')
plt.xticks([1,2,3,4])
plt.show()

# %% [markdown]
# ## Relacion entre tiempo en pantalla y reserva

# %%
web
# Out:
#         user_id                              device_id     session_id  \
# 51760   9015447                 yWOTGT6B-WzQU514Cqx1gL  1644253316189
# 14885   8820027                 LP42_fstvBPogWjh_1bkCg  1642913715699
# 3992    5510567                 AKERRpRODjl02b39AjfNb8  1642459615372
# 131349  8665203                 SxeKxvgE3mkec-e21Ej-bm  1647229337062
# 25970   8409083                 CttzrxBwYiDT93zwK93Xmt  1643398529809
# ...         ...                                    ...            ...
# 214144  5557797                 ITao0pyc-03mus8Rf9JcN5  1651362376439
# 214111  6220646   2e8d803d-822f-400c-9338-99a57ca8de9e  1651361409595
# 214150  5910763   1869c436-faaf-41ee-aa01-fb7c31b80954  1651362633868
# 214142    87114  2e357941-9c2d-49b3-86a5-0799d80a7913R  1651362348345
# 214156  9742739   1aad33ac-8e00-4f1a-abf7-5ec15d537706  1651362831138
#
#           device_model            session_date  total_sessions  total_events  \
# 51760          Android 2022-02-07 17:01:56.223               1             1
# 14885          Android 2022-01-23 04:55:17.124               1             9
# 3992           Android 2022-01-17 22:46:55.395               1             1
# 131349         Android 2022-03-14 03:42:17.095               1             9
# 25970          Android 2022-01-28 19:35:32.308               1             1
# ...                ...                     ...             ...           ...
# 214144         Android 2022-04-30 23:46:16.457               5           132
# 214111  moto g(8) plus 2022-04-30 23:30:09.595              21           145
# 214150        SM-A515F 2022-04-30 23:50:33.868              17           235
# 214142       SM-A705MN 2022-04-30 23:45:48.345              10           184
# 214156    moto e5 play 2022-04-30 23:53:51.138               2             6
#
#         total_vipphoto_selected  total_vip360view_selected  \
# 51760                         0                          0
# 14885                         0                          0
# 3992                          0                          0
# 131349                        0                          0
# 25970                         0                          0
# ...                         ...                        ...
# 214144                        0                          0
# 214111                        0                          0
# 214150                        0                          0
# 214142                        0                          0
# 214156                        0                          0
#
#         total_catalogfilter_selected  ...  total_sessions_prev  stock_id  \
# 51760                              0  ...                    1       NaN
# 14885                              5  ...                    2       NaN
# 3992                               0  ...                    1       NaN
# 131349                             2  ...                    2       NaN
# 25970                              0  ...                    1       NaN
# ...                              ...  ...                  ...       ...
# 214144                            32  ...                    4       NaN
# 214111                            10  ...                   19       NaN
# 214150                            34  ...                   17  182283.0
# 214142                             0  ...                   11       NaN
# 214156                             0  ...                    2       NaN
#
#              date  reserved  avg seconds on screen  mes_sesion  \
# 51760         NaT       0.0               0.000000           2
# 14885         NaT       0.0             143.000000           1
# 3992          NaT       0.0               0.000000           1
# 131349        NaT       0.0             189.500000           3
# 25970         NaT       0.0               0.000000           1
# ...           ...       ...                    ...         ...
# 214144        NaT       0.0            1619.000000           4
# 214111        NaT       0.0            4604.578947           4
# 214150 2022-05-01       1.0            2844.823529           4
# 214142        NaT       0.0          489033.090909           4
# 214156        NaT       0.0              45.000000           4
#
#         muinutes on screen  avg minutes on screen  mes de reserva  \
# 51760             0.000000               0.000000             NaN
# 14885             4.766667               2.383333             NaN
# 3992              0.000000               0.000000             NaN
# 131349            6.316667               3.158333             NaN
# 25970             0.000000               0.000000             NaN
# ...                    ...                    ...             ...
# 214144          107.933333              26.983333             NaN
# 214111         1458.116667              76.742982             NaN
# 214150          806.033333              47.413725             5.0
# 214142        89656.066667            8150.551515             NaN
# 214156            1.500000               0.750000             NaN
#
#         dia de reserva
# 51760              NaN
# 14885              NaN
# 3992               NaN
# 131349             NaN
# 25970              NaN
# ...                ...
# 214144             NaN
# 214111             NaN
# 214150             1.0
# 214142             NaN
# 214156             NaN
#
# [214160 rows x 35 columns]

# %%
tiempo_en_pantalla= web.groupby('user_id').agg(tiempo_total=('muinutes on screen','sum'),
                           reserva=('reserved','sum'))

# %%
def convirtio(x):
    if x > 0:
        return 1
    else:
        return 0
tiempo_en_pantalla['conversion']=tiempo_en_pantalla['reserva'].apply(convirtio)

# %%
tiempo_en_pantalla
# Out:
#          tiempo_total  reserva  conversion
# user_id
# 104         26.866667      0.0           0
# 136         90.316667      1.0           1
# 137         37.000000      0.0           0
# 166        122.850000      0.0           0
# 201          4.483333      0.0           0
# ...               ...      ...         ...
# 9756022      3.283333      0.0           0
# 9759725  59068.466667      0.0           0
# 9776787      1.433333      0.0           0
# 9790603   2938.883333      0.0           0
# 9856417      4.733333      0.0           0
#
# [140084 rows x 3 columns]

# %%
tiempo_en_pantalla.plot.scatter(x='tiempo_total',y='conversion')
tiempo_en_pantalla.plot.scatter(x='tiempo_total',y='reserva')
# Out:
# <AxesSubplot:xlabel='tiempo_total', ylabel='reserva'>

# %% [markdown]
# ## Relacion entre cantidad de dispositivos y reserva

# %%
cantidad_de_dispositivos.devices_used.unique()
# Out:
# array([ 1,  3,  2,  6,  7,  5, 11,  4,  8,  9], dtype=int64)

# %%
cantidad_de_dispositivos.loc[cantidad_de_dispositivos.devices_used == 11]
# Out:
#          devices_used  reserved
# user_id
# 2066               11       0.0
# 6126706            11       0.0

# %%
cantidad_de_dispositivos.loc[cantidad_de_dispositivos.reserved>0 ,'devices_used'].describe()
# Out:
# count    8863.000000
# mean        1.717477
# std         0.904399
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         2.000000
# max         8.000000
# Name: devices_used, dtype: float64

# %%
cantidad_de_dispositivos.loc[cantidad_de_dispositivos.reserved==0 ,'devices_used'].describe()
# Out:
# count    131221.000000
# mean          1.104915
# std           0.360302
# min           1.000000
# 25%           1.000000
# 50%           1.000000
# 75%           1.000000
# max          11.000000
# Name: devices_used, dtype: float64

# %%
web.loc[:,['user_id','total_events','reserved']]
# Out:
#         user_id  total_events  reserved
# 51760   9015447             1       0.0
# 14885   8820027             9       0.0
# 3992    5510567             1       0.0
# 131349  8665203             9       0.0
# 25970   8409083             1       0.0
# ...         ...           ...       ...
# 214144  5557797           132       0.0
# 214111  6220646           145       0.0
# 214150  5910763           235       1.0
# 214142    87114           184       0.0
# 214156  9742739             6       0.0
#
# [214160 rows x 3 columns]

# %%
web.groupby(['total_events','user_id']).agg(reserved=('reserved','count'))
# Out:
#                       reserved
# total_events user_id
# 1            793             1
#              1892            1
#              2128            1
#              2972            1
#              3227            1
# ...                        ...
# 27180        3655627         1
# 27797        6277756         1
# 28808        9643847         1
# 32690        9619016         1
# 39953        9719797         1
#
# [213640 rows x 1 columns]

# %%
web.groupby('user_id').agg(reserved=('reserved','count'),
                           devices_used=('device_id','nunique'))
# Out:
#          reserved  devices_used
# user_id
# 104             1             1
# 136             3             1
# 137             1             1
# 166             2             1
# 201             2             1
# ...           ...           ...
# 9756022         1             1
# 9759725         1             1
# 9776787         1             1
# 9790603         1             1
# 9856417         1             1
#
# [140084 rows x 2 columns]

# %%
devices=web.groupby('device_id').agg(reserved=('reserved','count'))

# %%
def correlation_heatmap(df):
    _ , ax = plt.subplots(figsize =(14, 12))
    colormap = sns.diverging_palette(220, 10, as_cmap = True)

    _ = sns.heatmap(
        df.corr(),
        cmap = colormap,
        square=True,
        cbar_kws={'shrink':.9 },
        ax=ax,
        annot=True,
        linewidths=0.1,vmax=1.0, linecolor='white',
        annot_kws={'fontsize':12 }
    )

    plt.title('TREE MAP KAVAK', y=1.05, size=15)

correlation_heatmap(web)

# %%
eventos=['reserved','total_cataloglist_viewed','total_catalogfilter_selected','total_home_viewed','total_vip360view_selected','total_color_selected','total_location_selected','total_make_selected','total_mileage_selected','total_version_selected','total_vip_viewed','total_vipphoto_selected','total_year_selected','total_model_selected','total_events']
eventos
# Out:
# ['reserved',
#  'total_cataloglist_viewed',
#  'total_catalogfilter_selected',
#  'total_home_viewed',
#  'total_vip360view_selected',
#  'total_color_selected',
#  'total_location_selected',
#  'total_make_selected',
#  'total_mileage_selected',
#  'total_version_selected',
#  'total_vip_viewed',
#  'total_vipphoto_selected',
#  'total_year_selected',
#  'total_model_selected',
#  'total_events']

# %%
web.groupby('reserved')[eventos].mean().T
# Out:
# reserved                             0.0         1.0
# reserved                        0.000000    1.000000
# total_cataloglist_viewed       33.074491   60.085228
# total_catalogfilter_selected   26.416915   53.072840
# total_home_viewed               4.213641   10.887023
# total_vip360view_selected       0.503987    1.043495
# total_color_selected            0.242570    0.295821
# total_location_selected         0.254932    0.340968
# total_make_selected             0.368868    0.461433
# total_mileage_selected          0.293004    0.366294
# total_version_selected          0.318505    0.387436
# total_vip_viewed               23.129716   48.133513
# total_vipphoto_selected         4.735817    8.117492
# total_year_selected             0.366740    0.439520
# total_model_selected            0.333872    0.399879
# total_events                  125.347169  251.599240

# %%
def percentaje(df):
    for i in df:
        df[i]=df[i]/df['total_events']*100
    return df
percentaje(eventos)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9916/288483305.py in <module>
#       3         df[i]=df[i]/df['total_events']*100
#       4     return df
# ----> 5 percentaje(eventos)
#
# ~\AppData\Local\Temp/ipykernel_9916/288483305.py in percentaje(df)
#       1 def percentaje(df):
#       2     for i in df:
# ----> 3         df[i]=df[i]/df['total_events']*100
#       4     return df
#       5 percentaje(eventos)
#
# TypeError: list indices must be integers or slices, not str

# %%
eventos=eventos.transpose()
eventos=eventos.loc[:,eventos.columns != 'total_events']
eventos

# %%
eventos['reserved']=eventos.index
